# %% [markdown]
# ## kafka 简单取数

# %%
import json, time
from confluent_kafka import Consumer, KafkaError

# %%
kafka = {
        "http": "192.168.50.85:19092",
        "offset": "earliest",
        "groupid": "apm-rca117",
        "topic.event": "dc_event",
        "topic.rca": "dc_rca"
    }

# %%
c = Consumer(
    {
        "bootstrap.servers": kafka["http"],  # kafka所在ip地址
        "group.id": kafka["groupid"],
        "enable.auto.commit": True,          # 是否自动提交offset，设为True时，每隔一段时间就会提交一次offset
        "auto.offset.reset": kafka["offset"],
        # "partition.assignment.strategy": "roundrobin",
    }
)
c.subscribe([kafka["topic.event"]])           # 为consumer分配分区
# c.subscribe([kafka["topic.event"]+"-0", kafka["topic.event"] + "-1", kafka["topic.event"] + "-2"])

# %%
# 没有break会不停的取数据
values = []
a = 0
while True:
    msg = c.poll(1)
    if msg is None:
        continue
    else:
        offset = msg.offset()
        partition = msg.partition()
        message = json.loads(msg.value())
        # message['offset'] = offset
        # message['partition'] = partition
        if ( (message["repeatableEvent"] == 1)
            and (message["status"] > 0)
            and (message["silence"] ==0) 
        ):
            a += 1
            print(message)
            values.append(message)
                # print(f"{message['monitorId']}:{message['triggerTime']}  partition:{msg.partition()},offset:{msg.offset()} ")
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# {'continuousCnt': 12, 'continuousEventId': '41498d7fd99c471087M9', 'startTriggerTime': 1704963240, 'lastTragerTime': 1704960840, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1704964500, 'cycle': 600, 'duration': 660, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 17.91%，高于 静态阈值0.00%，触发重要事件。', 'end': 1704964500, 'silence': 0, 'value': 0.17908333333333332, 'group': 'host:k8s-a2', 'view_unit': 'fractions', 'eventId': '41498d7fd99c471087M9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1704963600, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240111', 'trigger': {'host': ['k8s-a2']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 17.91%，高于 静态阈值0.00%，触发重要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1704963840, 'metrics': ['system.net.packetloss'], 'status': 3}
# {'continuousCnt': 12, 'continuousEventId': '55ffd5ed6e7d400fb1M9', 'startTriggerTime': 1704963240, 'lastTragerTime': 1704960840, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1704964500, 'cycle': 600, 'duration': 660, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a3】上【主机网络丢包率】实际值为 19.46%，高于 静态阈值0.00%，触发次要事件。', 'end': 1704964500, 'silence': 0, 'value': 0.19455555555555554, 'group': 'host:k8s-a3', 'view_unit': 'fractions', 'eventId': '55ffd5ed6e7d400fb1M9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1704963600, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240111', 'trigger': {'host': ['k8s-a3']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a3】上【主机网络丢包率】实际值为 19.46%，高于 静态阈值0.00%，触发次要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1704963840, 'metrics': ['system.net.packetloss'], 'status': 2}
# {'continuousCnt': 12, 'continuousEventId': 'dd5066f6635c4ace9cM9', 'startTriggerTime': 1704963240, 'lastTragerTime': 1704960840, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1704964500, 'cycle': 600, 'duration': 660, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a1】上【主机网络丢包率】实际值为 24.80%，高于 静态阈值0.00%，触发次要事件。', 'end': 1704964500, 'silence': 0, 'value': 0.24800000000000003, 'group': 'host:k8s-a1', 'view_unit': 'fractions', 'eventId': 'dd5066f6635c4ace9cM9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1704963600, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240111', 'trigger': {'host': ['k8s-a1']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a1】上【主机网络丢包率】实际值为 24.80%，高于 静态阈值0.00%，触发次要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1704963840, 'metrics': ['system.net.packetloss'], 'status': 2}
# {'continuousCnt': 14, 'continuousEventId': '41498d7fd99c471087M9', 'startTriggerTime': 1704963240, 'lastTragerTime': 1704960840, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1704964620, 'cycle': 600, 'duration': 780, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 11.51%，高于 静态阈值0.00%，触发重要事件。', 'end': 1704964620, 'silence': 0, 'value': 0.11508333333333333, 'group': 'host:k8s-a2', 'view_unit': 'fractions', 'eventId': '41498d7fd99c471087M9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1704963720, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240111', 'trigger': {'host': ['k8s-a2']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 11.51%，高于 静态阈值0.00%，触发重要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1704963840, 'metrics': ['system.net.packetloss'], 'status': 3}
# {'continuousCnt': 14, 'continuousEventId': '55ffd5ed6e7d400fb1M9', 'startTriggerTime': 1704963240, 'lastTragerTime': 1704960840, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1704964620, 'cycle': 600, 'duration': 780, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a3】上【主机网络丢包率】实际值为 2.66%，高于 静态阈值0.00%，触发次要事件。', 'end': 1704964620, 'silence': 0, 'value': 0.026555555555555554, 'group': 'host:k8s-a3', 'view_unit': 'fractions', 'eventId': '55ffd5ed6e7d400fb1M9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1704963720, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240111', 'trigger': {'host': ['k8s-a3']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a3】上【主机网络丢包率】实际值为 2.66%，高于 静态阈值0.00%，触发次要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1704963840, 'metrics': ['system.net.packetloss'], 'status': 2}
# {'continuousCnt': 14, 'continuousEventId': 'dd5066f6635c4ace9cM9', 'startTriggerTime': 1704963240, 'lastTragerTime': 1704960840, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1704964620, 'cycle': 600, 'duration': 780, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a1】上【主机网络丢包率】实际值为 13.71%，高于 静态阈值0.00%，触发次要事件。', 'end': 1704964620, 'silence': 0, 'value': 0.13707407407407407, 'group': 'host:k8s-a1', 'view_unit': 'fractions', 'eventId': 'dd5066f6635c4ace9cM9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1704963720, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240111', 'trigger': {'host': ['k8s-a1']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a1】上【主机网络丢包率】实际值为 13.71%，高于 静态阈值0.00%，触发次要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1704963840, 'metrics': ['system.net.packetloss'], 'status': 2}
# {'continuousCnt': 18, 'continuousEventId': '55ffd5ed6e7d400fb1M9', 'startTriggerTime': 1704963240, 'lastTragerTime': 1704960840, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1704964860, 'cycle': 600, 'duration': 1020, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a3】上【主机网络丢包率】实际值为 2.66%，高于 静态阈值0.00%，触发次要事件。', 'end': 1704964860, 'silence': 0, 'value': 0.026555555555555554, 'group': 'host:k8s-a3', 'view_unit': 'fractions', 'eventId': '55ffd5ed6e7d400fb1M9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1704963960, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240111', 'trigger': {'host': ['k8s-a3']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a3】上【主机网络丢包率】实际值为 2.66%，高于 静态阈值0.00%，触发次要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1704963840, 'metrics': ['system.net.packetloss'], 'status': 2}
# {'continuousCnt':
}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a1】上【主机网络丢包率】实际值为 44.49%，高于 静态阈值0.00%，触发次要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1704963840, 'metrics': ['system.net.packetloss'], 'status': 2}
# {'continuousCnt': 4, 'continuousEventId': 'f6daa72f43ae4c7fb9M9', 'startTriggerTime': 1704965580, 'lastTragerTime': 1704965820, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1704966360, 'cycle': 600, 'duration': 180, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 5.47%，高于 静态阈值0.00%，触发次要事件。', 'end': 1704966360, 'silence': 0, 'value': 0.054740740740740736, 'group': 'host:k8s-a2', 'view_unit': 'fractions', 'eventId': 'f6daa72f43ae4c7fb9M9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1704965460, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240111', 'trigger': {'host': ['k8s-a2']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 5.47%，高于 静态阈值0.00%，触发次要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1704966180, 'metrics': ['system.net.packetloss'], 'status': 2}
# {'continuousCnt': 21, 'continuousEventId': '9cb5442765004fc9b9M9', 'startTriggerTime': 1704964560, 'lastTragerTime': 1704964980, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1704966360, 'cycle': 600, 'duration': 1200, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a3】上【主机网络丢包率】实际值为 10.88%，高于 静态阈值0.00%，触发次要事件。', 'end': 1704966360, 'silence': 0, 'value': 0.10877777777777778, 'group': 'host:k8s-a3', 'view_unit': 'fractions', 'eventId': '9cb5442765004fc9b9M9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1704965460, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240111', 'trigger': {'host': ['k8s-a3']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a3】上【主机网络丢包率】实际值为 10.88%，高于 静态阈值0.00%，触发次要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1704965160, 'metrics': ['system.net.packetloss'], 'status': 2}
# {'continuousCnt': 43, 'continuousEventId': 'dd5066f6635c4ace9cM9', 'startTriggerTime': 1704963240, 'lastTragerTime': 1704960840, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1704966360, 'cycle': 600, 'duration': 2520, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a1】上【主机网络丢包率】实际值为 44.46%，高于 静态阈值0.00%，触发次要事件。', 'end': 1704966360, 'silence': 0, 'value': 0.4445925925925926, 'group': 'host:k8s-a1', 'view_unit': 'fractions', 'eventId': 'dd5066f6635c4ace9cM9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1704965460, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240111', 'trigger': {'host': ['k8s-a1']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a1】上【主机网络丢包率】实际值为 44.46%，高于 静态阈值0.00%，触发次要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1704963840, 'metrics': ['system.net.packetloss'], 'status': 2}
# ...
# {'continuousCnt': 19, 'continuousEventId': '5971c553a6634e0ba2M9', 'startTriggerTime': 1705054080, 'lastTragerTime': 1705053540, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1705055760, 'cycle': 600, 'duration': 1080, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 50.04%，高于 静态阈值0.00%，触发次要事件。', 'end': 1705055760, 'silence': 0, 'value': 0.5004, 'group': 'host:k8s-a2', 'view_unit': 'fractions', 'eventId': '5971c553a6634e0ba2M9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1705054860, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240112', 'trigger': {'host': ['k8s-a2']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 50.04%，高于 静态阈值0.00%，触发次要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1705054680, 'metrics': ['system.net.packetloss'], 'status': 2}
# {'continuousCnt': 21, 'continuousEventId': '5971c553a6634e0ba2M9', 'startTriggerTime': 1705054080, 'lastTragerTime': 1705053540, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1705055880, 'cycle': 600, 'duration': 1200, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 50.04%，高于 静态阈值0.00%，触发次要事件。', 'end': 1705055880, 'silence': 0, 'value': 0.5004, 'group': 'host:k8s-a2', 'view_unit': 'fractions', 'eventId': '5971c553a6634e0ba2M9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1705054980, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240112', 'trigger': {'host': ['k8s-a2']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 50.04%，高于 静态阈值0.00%，触发次要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1705054680, 'metrics': ['system.net.packetloss'], 'status': 2}
# {'continuousCnt': 24, 'continuousEventId': '5971c553a6634e0ba2M9', 'startTriggerTime': 1705054080, 'lastTragerTime': 1705053540, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1705056060, 'cycle': 600, 'duration': 1380, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 40.04%，高于 静态阈值0.00%，触发次要事件。', 'end': 1705056060, 'silence': 0, 'value': 0.4004, 'group': 'host:k8s-a2', 'view_unit': 'fractions', 'eventId': '5971c553a6634e0ba2M9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1705055160, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240112', 'trigger': {'host': ['k8s-a2']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 40.04%，高于 静态阈值0.00%，触发次要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1705054680, 'metrics': ['system.net.packetloss'], 'status': 2}
# {'continuousCnt': 26, 'continuousEventId': '5971c553a6634e0ba2M9', 'startTriggerTime': 1705054080, 'lastTragerTime': 1705053540, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1705056180, 'cycle': 600, 'duration': 1500, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 50.00%，高于 静态阈值0.00%，触发次要事件。', 'end': 1705056180, 'silence': 0, 'value': 0.5, 'group': 'host:k8s-a2', 'view_unit': 'fractions', 'eventId': '5971c553a6634e0ba2M9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1705055280, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240112', 'trigger': {'host': ['k8s-a2']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 50.00%，高于 静态阈值0.00%，触发次要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1705054680, 'metrics': ['system.net.packetloss'], 'status': 2}
# {'continuousCnt': 28, 'continuousEventId': '5971c553a6634e0ba2M9', 'startTriggerTime': 1705054080, 'lastTragerTime': 1705053540, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1705056300, 'cycle': 600, 'duration': 1620, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 40.00%，高于 静态阈值0.00%，触发次要事件。', 'end': 1705056300, 'silence': 0, 'value': 0.4, 'group': 'host:k8s-a2', 'view_unit': 'fractions', 'eventId': '5971c553a6634e0ba2M9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1705055400, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240112', 'trigger': {'host': ['k8s-a2']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 40.00%，高于 静态阈值0.00%，触发次要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1705054680, 'metrics': ['system.net.packetloss'], 'status': 2}
# {'continuousCnt': 30, 'continuousEventId': '5971c553a6634e0ba2M9', 'startTriggerTime': 1705054080, 'lastTragerTime': 1705053540, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1705056420, 'cycle': 600, 'duration': 1740, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 25.00%，高于 静态阈值0.00%，触发次要事件。', 'end': 1705056420, 'silence': 0, 'value': 0.25, 'group': 'host:k8s-a2', 'view_unit': 'fractions', 'eventId': '5971c553a6634e0ba2M9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1705055520, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240112', 'trigger': {'host': ['k8s-a2']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 25.00%，高于 静态阈值0.00%，触发次要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1705054680, 'metrics': ['system.net.packetloss'], 'status': 2}
# {'continuousCnt': 33, 'continuousEventId': '5971c553a6634e0ba2M9', 'startTriggerTime': 1705054080, 'lastTragerTime': 1705053540, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1705056600, 'cycle': 600, 'duration': 1920, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 33.75%，高于 静态阈值0.00%，触发次要事件。', 'end': 1705056600, 'silence': 0, 'value': 0.33749999999999997, 'group': 'host:k8s-a2', 'view_unit': 'fractions', 'eventId': '5971c553a6634e0ba2M9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1705055700, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240112', 'trigger': {'host': ['k8s-a2']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 33.75%，高于 静态阈值0.00%，触发次要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1705054680, 'metrics': ['system.net.packetloss'], 'status': 2}
# {'continuousCnt': 3, 'continuousEventId': '2ad88b587a3543e6bfM9', 'startTriggerTime': 1705055880, 'lastTragerTime': 1705054500, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1705056600, 'cycle': 600, 'duration': 120, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a3】上【主机网络丢包率】实际值为 0.01%，高于 静态阈值0.00%，触发次要事件。', 'end': 1705056600, 'silence': 0, 'value': 0.0001111111111111111, 'group': 'host:k8s-a3', 'view_unit': 'fractions', 'eventId': '2ad88b587a3543e6bfM9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1705055700, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240112', 'trigger': {'host': ['k8s-a3']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a3】上【主机网络丢包率】实际值为 0.01%，高于 静态阈值0.00%，触发次要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1705056480, 'metrics': ['system.net.packetloss'], 'status': 2}
# {'continuousCnt': 36, 'continuousEventId': '5971c553a6634e0ba2M9', 'startTriggerTime': 1705054080, 'lastTragerTime': 1705053540, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1705056780, 'cycle': 600, 'duration': 2100, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 33.75%，高于 静态阈值0.00%，触发次要事件。', 'end': 1705056780, 'silence': 0, 'value': 0.33749999999999997, 'group': 'host:k8s-a2', 'view_unit': 'fractions', 'eventId': '5971c553a6634e0ba2M9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1705055880, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240112', 'trigger': {'host': ['k8s-a2']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a2】上【主机网络丢包率】实际值为 33.75%，高于 静态阈值0.00%，触发次要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1705054680, 'metrics': ['system.net.packetloss'], 'status': 2}
# {'continuousCnt': 6, 'continuousEventId': '2ad88b587a3543e6bfM9', 'startTriggerTime': 1705055880, 'lastTragerTime': 1705054500, 'repeatableEvent': 1, 'source': 'DataBuff', 'triggerTime': 1705056780, 'cycle': 600, 'duration': 300, 'trgTrd': '静态阈值0.00%', 'eventName': '在最近10分钟内，【主机名称:k8s-a3】上【主机网络丢包率】实际值为 0.01%，高于 静态阈值0.00%，触发次要事件。', 'end': 1705056780, 'silence': 0, 'value': 0.0001111111111111111, 'group': 'host:k8s-a3', 'view_unit': 'fractions', 'eventId': '2ad88b587a3543e6bfM9', 'monitorId': 9, 'dd-api-key': 'NzhEMjlBOTk3MzkxRjk5MjQyMzMzQzI4', 'query': '{"1": {"A": {"by": ["host"], "aggs": "avg", "from": [], "types": ["基础设施", "主机", "网络"], "metric": "system.net.packetloss"}, "way": "threshold", "expr": "A", "unit": "fractions", "_scale": 1, "period": 600, "view_unit": "fractions", "comparison": ">", "thresholds": {"warning": 0, "critical": 0.7}, "time_aggregator": "avg", "evaluation_delay": 0, "no_data_timeframe": 0, "require_full_window": false}, "noData": "AND", "warning": "AND", "critical": "AND"}', 'start': 1705055880, 'triggerObjType': 'host', 'index': 'dc_monitor_event_20240112', 'trigger': {'host': ['k8s-a3']}, 'classification': 'singleMetric', 'priority': 0, 'message': '在最近10分钟内，【主机名称:k8s-a3】上【主机网络丢包率】实际值为 0.01%，高于 静态阈值0.00%，触发次要事件。', 'userId': 1, 'unit': 'fractions', 'thresholds': {'critical': 0.7, 'warning': 0, 'mName': 'system.net.packetloss'}, 'monitorTags': ['系统监控'], 'firstTragerTime': 1705056480, 'metrics': ['system.net.packetloss'], 'status': 2}

# %%
metrics = ['service.request_errors.pct', 'service.request.count', 'service.response.time', 'url.request_errors.pct', 'url.response.time', 'url.requests.count']
values = ['service.request_errors.pct']
intersection = set(metrics) & set(values)
if intersection:
    print(1)
# Out:
# %4|1704707331.966|MAXPOLL|rdkafka#consumer-2| [thrd:main]: Application maximum poll interval (300000ms) exceeded by 322ms (adjust max.poll.interval.ms for long-running message processing): leaving group

# %%
sorted([{'offset':i['offset'],'time':i['triggerTime'],'partition':i['partition']} for i in values], key=lambda x: x['time'])
# Out:
# [{'offset': 1702917, 'time': 1687846140, 'partition': 1},
#  {'offset': 1734841, 'time': 1687846200, 'partition': 0},
#  {'offset': 1724857, 'time': 1687846260, 'partition': 2},
#  {'offset': 1734846, 'time': 1687846320, 'partition': 0},
#  {'offset': 1724890, 'time': 1687846380, 'partition': 2}]

# %% [markdown]
# ___________

# %% [markdown]
# # 从kafka中取一段时间内的数据

# %%
from confluent_kafka import Consumer, KafkaError, TopicPartition, Message
import datetime, time, json

# %%
kafka = {}
kafka['http'] = '192.168.50.107:19092'
kafka['topicCtrl'] = 'dc_abnormal_control'
kafka['topicData'] = 'dc_abnormal_data'
kafka['offset'] = 'earliest'
kafka['groupid'] = 'AnomalyDetectTest01'

# %%
c = Consumer({
    'bootstrap.servers':kafka['http'], # kafka所在ip地址
    'group.id':time.time(),
    'enable.auto.commit':True, # 是否自动提交offset，设为True时，每隔一段时间就会提交一次offset
    'default.topic.config':{
        'auto.offset.reset':kafka['offset']
    }  
})

# %%
# 拉取昨天一天的数据，start_time、end_time这两个时间可以随便设置
now = datetime.datetime.now() - datetime.timedelta(days=1)
start_time = datetime.datetime.strptime(now.strftime('%Y-%m-%d 00:00:00'),'%Y-%m-%d %H:%M:%S')
end_time = datetime.datetime.strptime(now.strftime('%Y-%m-%d 23:59:59'),'%Y-%m-%d %H:%M:%S')

# %%
# 获取当前topic有多少个分区 
cluster_data = c.list_topics(topic = kafka['topicData'])
topic_data = cluster_data.topics[kafka['topicData']]
available_partitions = topic_data.partitions

# %%
start_tps = [TopicPartition(kafka['topicData'], index, int(start_time.timestamp() * 1000)) for index in range(len(available_partitions))]
start_offset = c.offsets_for_times(start_tps)
end_tps = [TopicPartition(kafka['topicData'], index, int(end_time.timestamp() * 1000)) for index in range(len(available_partitions))]
end_offset = c.offsets_for_times(end_tps)
c.assign(start_offset)

# %%
start_offset
# Out:
# [TopicPartition{topic=dc_abnormal_data,partition=0,offset=-1,error=None},
#  TopicPartition{topic=dc_abnormal_data,partition=1,offset=38239,error=None},
#  TopicPartition{topic=dc_abnormal_data,partition=2,offset=-1,error=None}]

# %%
values = []
while True:
    msg = c.poll(100) # poll：轮询一次过程中，在一定时间内broker可消费的数据，单位为ms，如这里的100,就是在0.1s内拉取数据返回到消费者端
    if msg is None:
        continue
    if msg.error():
        prinit('Consumer error:{}'.format(msg.error()))
        continue
    offset = msg.offset()
    if offset < end_offset[1].offset: # 有数据的在partition为1的topicpartition
        kafka_timestamp = msg.timestamp()[1] # 搞数据入kafka的时间戳
        kafka_value = json.loads(msg.value())
        values.append(kafka_value)
    else: 
        c.unassign()  # 超过当前Partition的话，停止订阅
        break
c.close()

# %%
end_offset[1].offset
# Out:
# 38899

# %%
values_to_json = {}
values_to_json['values'] = values

# %%
with open('../values.json', 'w') as f:
    json.dump(values_to_json, f, indent = 2, sort_keys = True, ensure_ascii = False)

# %% [markdown]
# ________

# %% [markdown]
# ### 从多个partition中取数

# %%
from confluent_kafka import Consumer, KafkaError, TopicPartition, Message
import datetime, time, json

# %%
kafka = {}
kafka['http'] = '192.168.50.107:19092'
kafka['topicCtrl'] = 'dc_abnormal_control'
kafka['topicData'] = 'dc_test_prophet'
kafka['offset'] = 'earliest'
kafka['groupid'] = 'AnomalyDetectTest01'

# %%
c = Consumer({
    'bootstrap.servers':kafka['http'], # kafka所在ip地址
    'group.id':time.time(),
    'enable.auto.commit':True, # 是否自动提交offset，设为True时，每隔一段时间就会提交一次offset
    'default.topic.config':{
        'auto.offset.reset':kafka['offset']
    }  
})

# %%
# 拉取昨天一天的数据，start_time、end_time这两个时间可以随便设置
start = datetime.datetime.now() - datetime.timedelta(days=40)
start_time = datetime.datetime.strptime(start.strftime('%Y-%m-%d 00:00:00'),'%Y-%m-%d %H:%M:%S')
end = datetime.datetime.now() - datetime.timedelta(days=40)
end_time = datetime.datetime.strptime(end.strftime('%Y-%m-%d 23:59:59'),'%Y-%m-%d %H:%M:%S')

# %%
# 获取当前topic有多少个分区 
cluster_data = c.list_topics(topic = kafka['topicData'])
topic_data = cluster_data.topics[kafka['topicData']]
available_partitions = topic_data.partitions

# %%
start_tps = [TopicPartition(kafka['topicData'], index, int(start_time.timestamp() * 1000)) for index in range(len(available_partitions))]
start_offset = c.offsets_for_times(start_tps)
end_tps = [TopicPartition(kafka['topicData'], index, int(end_time.timestamp() * 1000)) for index in range(len(available_partitions))]
end_offset = c.offsets_for_times(end_tps)
c.assign(start_offset)

# %%
end_offset
# Out:
# [TopicPartition{topic=dc_test_prophet,partition=0,offset=156,error=None},
#  TopicPartition{topic=dc_test_prophet,partition=1,offset=130,error=None},
#  TopicPartition{topic=dc_test_prophet,partition=2,offset=168,error=None}]

# %%
values = []
while True:
    msg = c.poll(100) # poll：轮询一次过程中，在一定时间内broker可消费的数据，单位为ms，如这里的100,就是在0.1s内拉取数据返回到消费者端
    if msg is None:
        continue
    if msg.error():
        prinit('Consumer error:{}'.format(msg.error()))
        continue
    offset = msg.offset()
    if offset < end_offset[0].offset: 
        kafka_timestamp = msg.timestamp()[1]/1000 # 搞数据入kafka的时间戳
        kafka_value = json.loads(msg.value())
        values.append(kafka_value)
    else: 
        c.unassign()  # 超过当前Partition的话，停止订阅
        break
c.close()

# %%
len(values)
# Out:
# 0

# %%
values = []
while True:
    msg = c.poll(100) # poll：轮询一次过程中，在一定时间内broker可消费的数据，单位为ms，如这里的100,就是在0.1s内拉取数据返回到消费者端
    if msg is None:
        continue
    if msg.error():
        prinit('Consumer error:{}'.format(msg.error()))
        continue
    offset = msg.offset()
    datapartitions = [i for i in end_offset if i.offset != -1]

    for i in datapartitions:
        if offset < i.offset: 
            kafka_timestamp = msg.timestamp()[1] # 搞数据入kafka的时间戳
            kafka_value = json.loads(msg.value())
            values.append(kafka_value)
        else: 
            c.unassign()  # 超过当前Partition的话，停止订阅
            break
c.close()

# %%
msg = c.poll(100)
msg.timestamp()
# Out:
# (1, 1649401570230)

# %%
len(values)
# Out:
# 0
