# %%
import Kdewithplot

# %%
file = '/home/weijunfei/NAB-master_new/data/realTraffic/speed_6005.csv'

# %%
time_data = Kdewithplot.Kdemodel.train_data(file,'Hour')
time_data
# Out:
# running time of time = hour: 10.244282722473145 s
# {'bandwidth': 1.1233240329780276, 'kernel': 'exponential'}

# %%
time_data = Kdemodel.Kdemodel.train_data(file,'Day')
time_data
# Out:
# running time of time = hour: 6.285269498825073 s
# {'bandwidth': 0.9770099572992254, 'kernel': 'exponential'}

# %%
time_data = Kdemodel.Kdemodel.train_data(file,'Weekday')
time_data
# Out:
# running time of time = hour: 2.93985915184021 s
# {'bandwidth': 1.5556761439304723, 'kernel': 'tophat'}

# %%
file = '/home/weijunfei/NAB-master_new/data/artificialWithAnomaly/art_daily_flatmiddle.csv'

# %%
time_data = Kdemodel.Kdemodel.train_data(file,'Hour')
time_data
# Out:
# running time of time = hour: 9.833371639251709 s
# {'bandwidth': 2.25701971963392, 'kernel': 'exponential'}

# %%
time_data = Kdemodel.Kdemodel.train_data(file,'Day')
time_data
# Out:
# running time of time = hour: 5.792465686798096 s
# {'bandwidth': 1.6297508346206444, 'kernel': 'exponential'}

# %%
time_data = Kdemodel.Kdemodel.train_data(file,'Weekday')
time_data
# Out:
# running time of time = hour: 2.9108059406280518 s
# {'bandwidth': 1.5556761439304723, 'kernel': 'exponential'}

# %%
import Kde
file = '/home/weijunfei/NAB-master_new/data/realTraffic/speed_6005.csv'
time_data = Kde.Kdemodel.train_data(file,'Hour')
time_data.head()
# Out:
# running time of time = hour: 9.86384916305542 s
#           value     score
# date
# 0     73.145161  0.020218
# 1     77.471698  0.070007
# 2     77.200000  0.062272
# 3     77.472727  0.070010
# 4     78.944444  0.080726

# %%
import Kde
file = '/home/weijunfei/NAB-master_new/data/realTraffic/speed_6005.csv'
time_data = Kde.Kdemodel.train_data(file,'Day')
time_data
# Out:
# running time of time = hour: 6.070439577102661 s
#                 value     score
# date
# 2015-08-31  81.043478  0.217329
# 2015-09-01  80.734694  0.196722
# 2015-09-02  81.375723  0.228359
# 2015-09-03  82.480663  0.156893
# 2015-09-04  84.068182  0.123692
# 2015-09-08  83.739583  0.123035
# 2015-09-09  80.893805  0.210125
# 2015-09-10  81.804054  0.226800
# 2015-09-11  81.684729  0.240390
# 2015-09-12  85.173913  0.074842
# 2015-09-13  84.261628  0.117015
# 2015-09-14  81.682692  0.240376
# 2015-09-15  80.604938  0.180586
# 2015-09-16  81.690763  0.240019
# 2015-09-17  77.608696  0.042454

# %%
import Kde
file = '/home/weijunfei/NAB-master_new/data/realTraffic/speed_6005.csv'
time_data = Kde.Kdemodel.train_data(file,'Weekday')
time_data
# Out:
# running time of time = hour: 2.985755681991577 s
#           value     score
# date
# 0     81.619048  0.229574
# 1     81.263374  0.229574
# 2     81.420561  0.229574
# 3     80.538012  0.183659
# 4     82.791557  0.229574
# 5     85.173913  0.091830
# 6     84.261628  0.137744

# %%
import os
import Kdewithplot
path = '/home/weijunfei/NAB-master_new/data/realTraffic'
filename = os.listdir(path)
filename
# Out:
# ['occupancy_6005.csv',
#  'occupancy_t4013.csv',
#  'speed_6005.csv',
#  'speed_7578.csv',
#  'speed_t4013.csv',
#  'TravelTime_387.csv',
#  'TravelTime_451.csv']

# %%
files = []
for i in range(len(filename)):     #拼接读入路径
    file = os.path.join(path,filename[i])
    files.append(file)

# %%
for i in range(len(files)):
    print(files[i])
    Kdewithplot.Kdemodel.train_data(file,'Hour')
    Kdewithplot.Kdemodel.train_data(file,'Day')
    Kdewithplot.Kdemodel.train_data(file,'Weekday')
# Out:
# /home/weijunfei/NAB-master_new/data/realTraffic/occupancy_6005.csv
# running time of time = hour: 9.868818998336792 s
# running time of time = hour: 21.02494525909424 s
# running time of time = hour: 2.8788280487060547 s
# /home/weijunfei/NAB-master_new/data/realTraffic/occupancy_t4013.csv
# running time of time = hour: 10.083518266677856 s
# running time of time = hour: 21.370849609375 s
# running time of time = hour: 2.900068998336792 s
# /home/weijunfei/NAB-master_new/data/realTraffic/speed_6005.csv
# running time of time = hour: 9.81856894493103 s
# running time of time = hour: 21.41137671470642 s
# running time of time = hour: 2.763866901397705 s
# /home/weijunfei/NAB-master_new/data/realTraffic/speed_7578.csv
# running time of time = hour: 10.035817623138428 s
# running time of time = hour: 21.202410221099854 s
# running time of time = hour: 2.8401577472686768 s
# /home/weijunfei/NAB-master_new/data/realTraffic/speed_t4013.csv
# running time of time = hour: 9.929500102996826 s
# ...

# %%
pwd
# Out:
# '/home/weijunfei/算法/KDE'
